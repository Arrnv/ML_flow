# %%
import pandas as pd

# %%
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.models import infer_signature

# %%
# load our dataset
X,y = datasets.load_iris(return_X_y=True)

# %%
# Spliting the data into train test split

X_train , X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# define hyperparqameters
params = {
    'penalty': 'l1',               
    'C': 0.5,                      
    'solver': 'saga',              
    'max_iter': 200,              
    'tol': 1e-3,                   
    'random_state': 42,            
    'fit_intercept': False,        
    'multi_class': 'ovr',          
    'verbose': 1,                  
    'warm_start': True             
}

# train the model 
lr = LogisticRegression(**params)
lr.fit(X_train, y_train)
# Out:
# Epoch 1, change: 1
# Epoch 2, change: 0.24490805
# Epoch 3, change: 0.11066835
# Epoch 4, change: 0.059747264
# Epoch 5, change: 0.049086177
# Epoch 6, change: 0.039821478
# Epoch 7, change: 0.029841111
# Epoch 8, change: 0.027525787
# Epoch 9, change: 0.024778514
# Epoch 10, change: 0.021798354
# Epoch 11, change: 0.017219048
# Epoch 12, change: 0.015371562
# Epoch 13, change: 0.014429162
# Epoch 14, change: 0.0122455
# Epoch 15, change: 0.011929575
# Epoch 16, change: 0.010206787
# Epoch 17, change: 0.0094523279
# Epoch 18, change: 0.0088768138
# Epoch 19, change: 0.0080932267
# Epoch 20, change: 0.0076516198
# Epoch 21, change: 0.0071999899
# Epoch 22, change: 0.0070036667
# Epoch 23, change: 0.0067802986
# Epoch 24, change: 0.0062645087
# Epoch 25, change: 0.0060743314
# Epoch 26, change: 0.0058771265
# Epoch 27, change: 0.0058381369
# Epoch 28, change: 0.0059012118
# Epoch 29, change: 0.0059949659
# Epoch 30, change: 0.006042588
# Epoch 31, change: 0.0060841894
# ...

# %%
y_preds = lr.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_preds)
accuracy
# Out:
# 0.9333333333333333

# %% [markdown]
# ### Mlfow tracking

# %%
mlflow.set_tracking_uri(uri='http://127.0.0.1:5000')

mlflow.set_experiment("MLflow quick start")

with mlflow.start_run():
    # Logging params
    mlflow.log_params(params)
    # logging metric i.e accuracy
    mlflow.log_metric("Accuracy", accuracy)
    # set tags 
    mlflow.set_tag("Training Info", "basic lr model for learning how mlflow works")
    
    # infer the model  signiture
    signature = infer_signature(X_train, lr.predict(X_train))
    
    # logging the model
    model_info  = mlflow.sklearn.log_model(
        sk_model=lr,
        artifact_path="iris_model",
        signature=signature,
        input_example = X_train,
        registered_model_name = "tracking-quickstart",
    )
# Out:
# 2024/12/29 18:36:02 INFO mlflow.tracking.fluent: Experiment with name 'MLflow quick start' does not exist. Creating a new experiment.
# Successfully registered model 'tracking-quickstart'.
# 2024/12/29 18:36:04 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: tracking-quickstart, version 1
# 🏃 View run charming-worm-364 at: http://127.0.0.1:5000/#/experiments/431852550513650710/runs/c4ffde511e534ed5acdaffa72907fab7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/431852550513650710
# Created version '1' of model 'tracking-quickstart'.

# %%
mlflow.set_tracking_uri(uri='http://127.0.0.1:5000')

mlflow.set_experiment("MLflow quick start")

with mlflow.start_run():
    # Logging params
    mlflow.log_params(params)
    # logging metric i.e accuracy
    mlflow.log_metric("Accuracy", accuracy)
    # set tags 
    mlflow.set_tag("Training Info", "basic lr model for learning how mlflow works")
    
    # infer the model  signiture
    signature = infer_signature(X_train, lr.predict(X_train))
    
    # logging the model
    model_info  = mlflow.sklearn.log_model(
        sk_model=lr,
        artifact_path="iris_model",
        signature=signature,
        input_
    ],
    [
      4.8,
      3.4,
      1.9,
      0.2
    ],
    [
      5.2,
      3.4,
      1.4,
      0.2
    ],
    [
      6.7,
      3.1,
      4.4,
      1.4
    ],
    [
      5.8,
      2.7,
      3.9,
      1.2
    ],
    [
      6.1,
      2.9,
      4.7,
      1.4
    ],
    [
      4.9,
      2.4,
      3.3,
      1.0
    ],
    [
      6.0,
      2.7,
      5.1,
      1.6
    ],
    [
      6.0,
      3.4,
      4.5,
      1.6
    ],
    [
      5.5,
      2.4,
      3.8,
      1.1
    ],
    [
      6.5,
      2.8,
      4.6,
      1.5
    ],
    [
      5.8,
      2.7,
      5.1,
      1.9
    ],
    [
      5.4,
      3.4,
      1.7,
      0.2
    ],
    [
      6.8,
      3.2,
      5.9,
      2.3
    ],
    [
      5.8,
      2.7,
      4.1,
      1.0
    ],
    [
      6.3,
      2.3,
      4.4,
      1.3
    ],
    [
      5.6,
      3.0,
      4.1,
      1.3
    ],
    [
      5.0,
      3.4,
      1.5,
      0.2
    ],
    [
      6.5,
      3.0,
      5.8,
      2.2
    ],
    [
      4.6,
      3.1,
      1.5,
      0.2
    ],
    [
      6.7,
      3.3,
      5.7,
      2.5
    ],
    [
      6.1,
      2.6,
      5.6,
      1.4
    ],
    [
      7.9,
      3.8,
      6.4,
      2.0
    ],
    [
      5.8,
      2.7,
      5.1,
      1.9
    ],
    [
      4.3,
      3.0,
      1.1,
      0.1
    ],
    [
      5.2,
      4.1,
      1.5,
      0.1
    ],
    [
      7.2,
      3.6,
      6.1,
      2.5
    ],
    [
      5.8,
      2.8,
      5.1,
      2.4
    ],
    [
      6.6,
      3.0,
      4.4,
      1.4
    ],
    [
      6.8,
      3.0,
      5.5,
      2.1
    ],
    [
      6.0,
      2.9,
      4.5,
      1.5
    ],
    [
      4.9,
      2.5,
      4.5,
      1.7
    ],
    [
      4.6,
      3.4,
      1.4,
      0.3
    ],
    [
      6.3,
      3.3,
      6.0,
      2.5
    ],
    [
      4.9,
      3.1,
      1.5,
      0.1
    ],
    [
      6.1,
      2.8,
      4.7,
      1.2
    ],
    [
      5.9,
      3.2,
      4.8,
      1.8
    ],
    [
      4.7,
      3.2,
      1.6,
      0.2
    ],
    [
      6.3,
      2.7,
      4.9,
      1.8
    ],
    [
      5.0,
      2.0,
      3.5,
      1.0
    ],
    [
      4.7,
      3.2,
      1.3,
      0.2
    ],
    [
      4.4,
      3.0,
      1.3,
      0.2
    ],
    [
      7.7,
      2.6,
      6.9,
      2.3
    ],
    [
      6.3,
      3.3,
      4.7,
      1.6
    ],
    [
      5.8,
      2.6,
      4.0,
      1.2
    ],
    [
      5.1,
      3.8,
      1.6,
      0.2
    ],
    [
      6.3,
      2.9,
      5.6,
      1.8
    ],
    [
      6.4,
      3.1,
      5.5,
      1.8
    ],
    [
      5.2,
      3.5,
      1.5,
      0.2
    ],
    [
      4.6,
      3.6,
      1.0,
      0.2
    ],
    [
      6.7,
      3.1,
      4.7,
      1.5
    ],
    [
      5.4,
      3.7,
      1.5,
      0.2
    ],
    [
      6.9,
      3.2,
      5.7,
      2.3
    ],
    [
      6.4,
      3.2,
      5.3,
      2.3
    ],
    [
      5.7,
      2.5,
      5.0,
      2.0
    ],
    [
      5.4,
      3.0,
      4.5,
      1.5
    ],
    [
      6.4,
      2.8,
      5.6,
      2.2
    ],
    [
      7.6,
      3.0,
      6.6,
      2.1
    ],
    [
      5.4,
      3.9,
      1.7,
      0.4
    ],
    [
      6.2,
      3.4,
      5.4,
      2.3
    ],
    [
      5.7,
      2.6,
      3.5,
      1.0
    ],
    [
      4.9,
      3.1,
      1.5,
      0.2
    ],
    [
      7.7,
      3.8,
      6.7,
      2.2
    ],
    [
      4.8,
      3.4,
      1.6,
      0.2
    ],
    [
      5.0,
      3.6,
      1.4,
      0.2
    ],
    [
      6.9,
      3.1,
      5.4,
      2.1
    ]
  ]
}"""

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
# Out:
# array([2, 1, 0, 2, 2, 0, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 0, 1, 0, 2, 0,
#        1, 1, 1, 2, 2, 1, 2, 1, 0, 1, 2, 1, 1, 0, 1, 0, 1, 2, 2, 2, 1, 2,
#        0, 1, 0, 2, 0, 1, 0, 2, 1, 2, 0, 0, 0, 1, 1, 1, 1, 2, 1, 1, 1, 2,
#        0, 2, 1, 1, 1, 0, 2, 0, 2, 2, 2, 2, 0, 0, 2, 2, 1, 2, 1, 1, 0, 2,
#        0, 1, 2, 0, 2, 1, 0, 0, 2, 1, 1, 0, 2, 2, 0, 0, 1, 0, 2, 2, 2, 1,
#        2, 2, 0, 2, 1, 0, 2, 0, 0, 2])

# %% [markdown]
# # load the model in the form of genric python function

# %%
loaded_model = mlflow.pyfunc.load_model(model_uri)
